# %% [markdown]
# # Table 1

# %%
import pandas as pd

file = "Table1/table-1-8.xlsx"

# To print jut title like all races, asian, white alone etc, just change the file name 
df_title = pd.read_excel(file, header=None)
# dynamically printing title
print("\033[1m" + "Title: " + df_title.iloc[3, 0]  + "\033[0m")

# headers on row 5
df = pd.read_excel(file, header=5)

# ":" means select all rows, 0 is for the column
# this just gets rid of the tabs in the first column because they look weird when doing df.head()
# turning regex on means it'll find the \t anywhere in the string
df.iloc[:,0] = df.iloc[:,0].replace("\t", "", regex=True) 

# These rows were just descriptions of the rows underneath
# 0 said Both Sexes, 15 said Male, 30 said Female
df = df.drop([0, 15, 30])
df.replace('Z', 0, inplace=True)

all_both_sex = df.iloc[0:14].copy()
all_male = df.iloc[14:28].copy()     
all_female = df.iloc[28:42].copy()   

all_both_sex.rename(columns={df.columns[0]: 'Both Sex'}, inplace=True)
all_male.rename(columns={df.columns[0]: 'Male'}, inplace=True)
all_female.rename(columns={df.columns[0]: 'Female'}, inplace=True)

all_male
# Out:
# Title: Black Alone or in Combination
#                   Male    Total  None  1st - 4th grade  5th - 6th grade  \
# 16   18 years and over  15987.0  37.0             70.0            100.0
# 17      18 to 24 years   2262.0   0.0              0.0              4.0
# 18   25 years and over  13725.0  37.0             70.0             95.0
# 19      25 to 29 years   1723.0   2.0              0.0              9.0
# 20      30 to 34 years   1735.0   1.0              1.0              4.0
# 21      35 to 39 years   1544.0   6.0             10.0              2.0
# 22      40 to 44 years   1371.0   0.0             12.0              6.0
# 23      45 to 49 years   1228.0   8.0              1.0              3.0
# 24      50 to 54 years   1264.0   3.0              3.0              7.0
# 25      55 to 59 years   1257.0   3.0              6.0             10.0
# 26      60 to 64 years   1103.0   4.0             10.0              6.0
# 27      65 to 69 years    999.0   2.0              4.0              7.0
# 28      70 to 74 years    683.0   3.0             18.0             12.0
# 29   75 years and over    817.0   6.0              5.0             29.0
#
#     7th - 8th grade  9th grade  10th grade  11th grade2  \
# 16            156.0      171.0       265.0       1051.0
# 17              6.0       20.0        32.0        324.0
# 18            150.0      152.0       233.0        728.0
# 19              9.0        4.0        22.0         52.0
# 20             17.0        2.0         9.0         65.0
# 21             12.0       13.0        37.0         86.0
# 22             11.0       12.0        26.0         65.0
# 23              1.0       15.0        17.0         48.0
# 24             13.0       12.0        16.0         68.0
# 25              9.0       18.0        24.0         76.0
# 26             20.0       17.0        21.0        108.0
# 27             19.0       23.0        20.0         80.0
# 28             10.0        9.0        15.0         26.0
# 29             31.0       27.0        26.0         55.0
#
#     High school graduate3  Some college, no degree  \
# 16                 6163.0                   3006.0
# 17                  981.0                    681.0
# 18                 5182.0                   2325.0
# 19                  772.0                    329.0
# 20                  647.0                    342.0
# 21                  490.0                    251.0
# 22                  477.0                    247.0
# 23                  452.0                    209.0
# 24                  522.0                    180.0
# 25                  509.0                    196.0
# 26                  424.0                    170.0
# 27                  362.0                    165.0
# 28                  226.0                    124.0
# 29                  301.0                    111.0
#
#     Associate's degree, occupational  Associate's degree, academic  \
# 16                             623.0                         827.0
# 17                              50.0                          40.0
# 18                             573.0                         787.0
# 19                              38.0                          72.0
# 20                              73.0                         148.0
# 21                              76.0                          93.0
# 22                              51.0                          70.0
# 23                              74.0                          67.0
# 24                              53.0                          73.0
# 25                              51.0                          74.0
# 26                              45.0                          54.0
# 27                              55.0                          64.0
# 28                              22.0                          39.0
# 29                              34.0                          33.0
#
#     Bachelor's degree  Master's degree  Professional degree  Doctoral degree
# 16             2367.0            862.0                128.0            161.0
# 17              117.0              7.0                  0.0              0.0
# 18             2251.0            855.0                128.0            161.0
# 19              347.0             41.0                 22.0              5.0
# 20              281.0            119.0                 22.0              4.0
# 21              340.0            100.0                 16.0             10.0
# 22              242.0            103.0                 17.0             34.0
# 23              213.0            100.0                  9.0             11.0
# 24              204.0             74.0                 13.0             22.0
# 25              188.0             79.0                  7.0              9.0
# 26              124.0             69.0                  9.0             23.0
# 27              126.0             59.0                  2.0              9.0
# 28              100.0             60.0                  4.0             17.0
# 29               85.0             51.0                  6.0             17.0

# %% [markdown]
# # Table 2

# %%
file = "Table2/table-2-3.xlsx"


# To print jut title like both sexes, male, female, just change the file name 
df_title = pd.read_excel(file, header=None)
# dynamically printing title
print("\033[1m" + "Title: " + df_title.iloc[3, 0]  + "\033[0m")


# headers on row 5
df = pd.read_excel(file, header=5)
df.iloc[:,0] = df.iloc[:,0].replace("\t", "", regex=True) 

marital_status = df.iloc[2:8].copy()  
household_relationship = df.iloc[9:19].copy()  
citizenship = df.iloc[20:26].copy() 
year_of_entry  = df.iloc[27:33].copy()  
labor_force_status = df.iloc[34:37].copy()  
occupation = df.iloc[38:49].copy()  
industry = df.iloc[50:64].copy()  

# Renaming first columns
marital_status.rename(columns={df.columns[0]: df.iloc[1, 0]}, inplace=True)
household_relationship.rename(columns={df.columns[0]: df.iloc[8, 0]}, inplace=True)
citizenship.rename(columns={df.columns[0]: df.iloc[19, 0]}, inplace=True)
year_of_entry.rename(columns={df.columns[0]: df.iloc[26, 0]}, inplace=True)
labor_force_status.rename(columns={df.columns[0]: df.iloc[33, 0]}, inplace=True)
occupation.rename(columns={df.columns[0]: df.iloc[37, 0]}, inplace=True)
industry.rename(columns={df.columns[0]: df.iloc[49, 0]}, inplace=True)

marital_status
household_relationship
citizenship
# year_of_entry
# labor_force_status
# occupation
# industry
# Out:
# Title: Male
#    Citizenship, Nativity, and Year of Entry    Total  None - 8th grade  \
# 20                              Native born  89951.0            1179.0
# 21                        Native parentage5  81030.0            1029.0
# 22              Foreign or mixed parentage6   8921.0             150.0
# 23                             Foreign born  20028.0            2862.0
# 24                      Naturalized citizen   9730.0             821.0
# 25                            Not a citizen  10297.0            2041.0
#
#     9th - 11th grade2  High school graduate3  Some college, no degree  \
# 20             4516.0                27715.0                  14413.0
# 21             4093.0                25382.0                  13011.0
# 22              423.0                 2333.0                   1401.0
# 23             1787.0                 5366.0                   1673.0
# 24              560.0                 2414.0                   1007.0
# 25             1227.0                 2952.0                    666.0
#
#     Associate's degree4  Bachelor's degree  Master's degree  \
# 20               9376.0            21283.0           7999.0
# 21               8470.0            19026.0           7072.0
# 22                906.0             2258.0            927.0
# 23               1240.0             3908.0           2157.0
# 24                789.0             2345.0           1145.0
# 25                451.0             1563.0           1012.0
#
#     Professional degree  Doctoral degree
# 20               1536.0           1933.0
# 21               1280.0           1666.0
# 22                256.0            267.0
# 23                324.0            711.0
# 24                218.0            431.0
# 25                106.0            281.0

# %% [markdown]
# # Table 3

# %%
file = "Table3/table-3.xlsx"

df_title = pd.read_excel(file, header=None)
# dynamically printing title
print("\033[1m" + "Title: " + df_title.iloc[1, 0]  + "\033[0m")


df = pd.read_excel(file, header=[3, 4])
df.iloc[:,0] = df.iloc[:,0].replace("\t", "", regex=True) 
df.rename(columns={df.columns[0][1]: ''}, inplace=True) # this was an unamed level previously

total = df.iloc[0:1].copy()

ele_or_hs_no_dip = df.iloc[2:10].copy()
ele_or_hs_no_dip.rename(columns={df.columns[0][1]: df.iloc[1, 0]}, inplace=True)

ele_or_hs_dip = df.iloc[11:19].copy()
ele_or_hs_dip.rename(columns={df.columns[0][1]: df.iloc[10, 0]}, inplace=True)

hs_dip = df.iloc[20:21].copy()

coll_no_deg = df.iloc[22:27].copy()
coll_no_deg.rename(columns={df.columns[0][1]: df.iloc[21, 0]}, inplace=True)

assoc_deg_voc = df.iloc[28:33].copy()
assoc_deg_voc.rename(columns={df.columns[0][1]: df.iloc[27, 0]}, inplace=True)

assoc_deg_acad = df.iloc[34:39].copy()
assoc_deg_acad.rename(columns={df.columns[0][1]: df.iloc[33, 0]}, inplace=True)

bach_deg_or_more = df.iloc[40:44].copy()
bach_deg_or_more.rename(columns={df.columns[0][1]: df.iloc[39, 0]}, inplace=True)

bach_deg_or_more
# Out:
# Title: Table 3. Detailed Years of School Completed by People 25 Years and Over by Sex, Age Groups, Race and Hispanic Origin: 2022
#       Detailed years of school All people             Male           Female  \
#    Bachelor's degree or higher     Number Percent   Number Percent   Number
# 40           Bachelor's degree    53045.0    23.4  25192.0    22.9  27853.0
# 41            Master's degree2    23881.0    10.6  10156.0     9.2  13725.0
# 42         Professional degree     3444.0     1.5   1860.0     1.7   1584.0
# 43            Doctorate degree     4848.0     2.1   2644.0     2.4   2203.0
#
#            25 to 34 years old         35 to 54 years old  ...    White  \
#    Percent             Number Percent             Number  ...   Number
# 40      24            12735.0    28.6            20874.0  ...  42000.0
# 41    11.8             4371.0     9.8            10412.0  ...  18299.0
# 42     1.4              491.0     1.1             1419.0  ...   2766.0
# 43     1.9              722.0     1.6             1960.0  ...   3553.0
#
#            Non-Hispanic White           Black          Asian          \
#    Percent             Number Percent  Number Percent Number Percent
# 40    23.9            37335.0    26.1  4897.0    17.1   4782    32.6
# 41    10.4            16774.0    11.7  2292.0       8   2774    18.9
# 42     1.6             2473.0     1.7   281.0       1    358     2.4
# 43       2             3302.0     2.3   413.0     1.4    778     5.3
#
#    Hispanic (of any race)
#                    Number Percent
# 40                 5348.0    14.5
# 41                 1737.0     4.7
# 42                  330.0     0.9
# 43                  282.0     0.8
#
# [4 rows x 23 columns]

# %% [markdown]
# # Analyzing Education Attainment Across Generations
# - There are some pretty big differences between age groups
# - Can analyze in depth more for sure

# %%
import matplotlib.pyplot as plt

def edu_line_chart(file):
    # headers on row 5
    df_title = pd.read_excel(file, header=None)
    # dynamically printing title
    print("\033[1m" + "Title: " + df_title.iloc[3, 0]  + "\033[0m")

    df = pd.read_excel(file, header=5)

    # ":," means select all rows, 0 is for the column
    # this just gets rid of the tabs in the first column because they look weird when doing df.head()
    # turning regex on means it'll find the \t anywhere in the string
    df.iloc[:, 0] = df.iloc[:, 0].replace("\t", "", regex=True) 

    # 0 is a description, 1 and 3 are an aggregate of age groups
    df = df.drop([0, 1, 3])

    df = df.iloc[0:12].copy()
    df.set_index(df.columns[0], inplace=True)

    df.replace('Z', 0, inplace=True)
    # exclude the first two columns and plot the rest
    df = df.iloc[:, 2:].transpose()  # Exclude the first two columns

    # split the dataframe for plotting
    young_df = df.iloc[:, 0:6]
    old_df = df.iloc[:, 6:]

    plt.figure(figsize=(10, 5))
    for c in young_df.columns:
        plt.plot(young_df.index, young_df[c], marker='o', label=c)

    plt.xlabel("Educational Attainment")
    plt.ylabel("Total (Thousands)")
    plt.title("Educational Attainment by Age Group (First Half) ")
    plt.legend(title="Age Group")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(10, 5))
    for c in old_df.columns:
        plt.plot(old_df.index, old_df[c], marker='o', label=c)

    plt.xlabel("Educational Attainment")
    plt.ylabel("Total (Thousands)")
    plt.title("Educational Attainment by Age Group (Second Half)")
    plt.legend(title="Age Group")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

for i in range(1,10):
    edu_line_chart(f"Table1/table-1-{i}.xlsx")
# Out:
# Title: All Races
# Title: White Alone
# Title: White Alone, not Hispanic
# Title: Black Alone
# Title: Asian Alone
# Title: Hispanic (any race)
# Title: White Alone or in Combination
# Title: Black Alone or in Combination
# Title: Asian Alone or in Combination
