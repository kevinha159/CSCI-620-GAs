# %%
import pandas

file = "Table1/table-1-1.xlsx"

df = pandas.read_excel(file)

print(df)
# Out:
#    Table with row headers in column A and column headers in rows 5 through 6  \
# 0   Table 1. Educational Attainment of the Populat...
# 1   (Numbers in thousands. Civilian noninstitution...
# 2                                           All Races
# 3                                      Characteristic
# 4                                                 NaN
# 5                                          Both Sexes
# 6                                \t 18 years and over
# 7                                \t\t  18 to 24 years
# 8                                \t 25 years and over
# 9                                \t\t  25 to 29 years
# 10                               \t\t  30 to 34 years
# 11                               \t\t  35 to 39 years
# 12                               \t\t  40 to 44 years
# 13                               \t\t  45 to 49 years
# 14                               \t\t  50 to 54 years
# 15                               \t\t  55 to 59 years
# ...
